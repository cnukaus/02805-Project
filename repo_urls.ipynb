# %%
from bs4 import BeautifulSoup
import urllib.request
from lxml import etree
import pickle
import os
import glob
import re
import sys

# %%
crypto = r'bitcoin'

# %%
def getUrl(crypto_name):
    url = r'https://www.coingecko.com/en/coins/' + crypto_name + r'/developer'
    req = urllib.request.Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    html = urllib.request.urlopen(req).read()
    soup = BeautifulSoup(html, 'lxml')
    try:
        base_url = soup.find('a', href=True, text='Code Repository')['href']
        return base_url
    except TypeError:
        return None

# %%
def getNames():
    url = r'https://coinmarketcap.com/coins/views/all/'
    response = urllib.request.urlopen(url)
    soup = BeautifulSoup(response, 'lxml')
    names_divs = soup.findAll('a', { 'class' : 'currency-name-container' })
    names_text = [div.text for div in names_divs]
    return names_text

# %%
crypto_currency_names = [name.replace(' ','-').lower() for name in getNames()]
N = len(crypto_currency_names)

print('There are ' + str(N) + ' crypto-currencies.   -source coinmarketcap.com')
print(crypto_currency_names[0:5]) # (These are the top five)
# Out:
# There are 916 crypto-currencies.   -source coinmarketcap.com
# ['bitcoin', 'ethereum', 'bitcoin-cash', 'ripple', 'bitcoin-gold']

# %%
# Create dict of  {cryto-currencey: github-url,} eg {'bitcoin: https://github.com/bitcoin/bitcoin}
cryptoName_gitUrl_dict = {}

for i,name in enumerate(crypto_currency_names):
    try: 
        git_url = getUrl(name)
    except:
        git_url = None

    cryptoName_gitUrl_dict[name] = git_url
    
    # Prints progress (%) to standard output
    if (i % 90 == 0):
        print(str("\r{0}".format(round((float(i)/N)*100),0)) + r'% ...')
# Out:
# 0% ...
# 10% ...
# 20% ...
# 29% ...
# 39% ...
# 49% ...
# 59% ...
# 69% ...
# 79% ...
# 88% ...
# 98% ...

# %%
# Check our results of assigning a Github repo to each repository
for name in crypto_currency_names[0:5]:
    print(cryptoName_gitUrl_dict[name])
# Out:
# https://github.com/bitcoin/bitcoin
# https://github.com/ethereum/go-ethereum
# https://github.com/Bitcoin-ABC/bitcoin-abc
# https://github.com/ripple/rippled
# https://github.com/BTCGPU/BTCGPU

# %%
cryptoName_gitUrl_dict['bitdeal']

# %%
# Pickle dict to current directory. {'bitcoin: https://github.com/bitcoin/bitcoin}
with open('./cryptoName_gitUrl_dict.pickle', 'wb') as handle:
    pickle.dump(cryptoName_gitUrl_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
nones = {k:v for k,v in cryptoName_gitUrl_dict.items() if v is None}
print('Number of crypto-currencies without a Github repo: ' + str(len(nones)))
# Out:
# Number of crypto-currencies without a Github repo: 479

# %%
# Inspect the crypto-currencies that DON'T have a GitHub repository.
for crypto in nones:
    print(crypto)
# Out:
# stellar-lumens
# byteball-bytes
# metaverse-etp
# vechain
# b3coin
# cryptonex
# kucoin-shares
# i/o-coin
# atbcoin
# decent
# crown
# e-coin
# peerplays
# the-champcoin
# bitcloud
# compcoin
# voxels
# sphere
# pascal-coin
# credence-coin
# kore
# global-curren...
# myriad
# thegcccoin
# neutron
# artbyte
# equitrader
# europecoin
# bela
# internet-of-p...
# hempcoin
# xgox
# xp
# condensate
# e-gulden
# putincoin
# atmos
# zennies
# zoin
# supercoin
# mao-zedong
# draftcoin
# growers-inter...
# zephyr
# greencoin
# eboost
# bytecent
# pure
# helleniccoin
# netko
# hicoin
# kekcoin
# briacoin
# linx
# happycoin
# allsafe
# sacoin
# footy-cash
# unify
# shield
# zero
# gcoin
# solaris
# 42-coin
# inflationcoin
# smileycoin
# elementrem
# blakestar
# universal-cur...
# tychocoin
# altcommunity-...
# goldreserve
# 808coin
# valorbit
# atomic-coin
# litebar
# postcoin
# scorecoin
# kilocoin
# ecocoin
# prototanium
# devcoin
# elcoin
# chancoin
# reecoin
# evotion
# wyvern
# womencoin
# prcoin
# francs
# coinonatx
# pascal-lite
# virta-unique-...
# tristar-coin
# doubloon
# litecoin-plus
# nevacoin
# beatcoin
# eryllium
# printerium
# bitcurrency
# morningstar
# magnum
# selfiecoin
# project-x
# levoplus
# litecoin-ultra
# harmonycoin
# digital-money...
# stakecoin
# crypto-bullion
# atc-coin
# coin(o)
# colossuscoin-v2
# russiacoin
# carboncoin
# ufo-coin
# shorty
# btctalkcoin
# metalcoin
# kobocoin
# iticoin
# ultimate-secu...
# version
# ohm
# aurumcoin
# globalcoin
# icoin
# universe
# platinumbar
# guncoin
# qubitcoin
# rubies
# 8bit
# lanacoin
# wayguide
# kayicoin
# emoneypower
# i0coin
# lottocoin
# sproutsextreme
# bigup
# darsek
# petrodollar
# eurocoin
# bolivarcoin
# piecoin
# evil-coin
# unicoin
# leviarcoin
# mineum
# honey
# chesscoin
# yacoin
# satoshimadness
# bittokens
# leacoin
# flaxscript
# globalboost-y
# emerald-crypto
# corgicoin
# gapcoin
# philosopher-s...
# berncash
# global-tour-coin
# cannation
# coin2.1
# sling
# c-bit
# bumbacoin
# tekcoin
# 020londoncoin
# antibitcoin
# ammo-rewards
# bitcoinfast
# aquariuscoin
# unrealcoin
# tattoocoin-(s...
# bitcoin-planet
# rupaya
# firecoin
# paycon
# dollarcoin
# halcyon
# x-coin
# prime-xi
# aricoin
# parallelcoin
# marscoin
# redcoin
# chronos
# tigercoin
# kibicoin
# islacoin
# bitquark
# sixeleven
# marijuanacoin
# vectorai
# independent-m...
# dreamcoin
# spots
# slimcoin
# kittehcoin
# creatio
# californium
# sooncoin
# gpu-coin
# mustangcoin
# compucoin
# gameunits
# allion
# icobid
# billarycoin
# ponzicoin
# tajcoin
# jin-coin
# healthywormcoin
# bitz
# ronpaulcoin
# gold-pressed-...
# securecoin
# popularcoin
# jewels
# beavercoin
# zetamicron
# bitcoin-21
# debitcoin
# blackstar
# cryptoescudo
# neuro
# artex-coin
# money
# guccionecoin
# bipcoin
# zayedcoin
# braincoin
# cashcoin
# coimatic-2.0
# cryptoworldx-...
# photon
# arbit
# warp
# bitcoal
# digital-rupees
# mindcoin
# vault-coin
# litecred
# coinonat
# orlycoin
# flavorcoin
# cthulhu-offer...
# bowscoin
# pulse
# crtcoin
# fuzzballs
# anarchistsprime
# g3n
# songcoin
# cabbage
# gbcgoldcoin
# bbqcoin
# iconic
# plncoin
# impact
# impulsecoin
# gamebet-coin
# milocoin
# ibank
# tagrcoin
# ride-my-car
# dappster
# bioscrypto
# agrolifecoin
# wild-beast-block
# luna-coin
# letitride
# vip-tokens
# blazecoin
# kingn-coin
# posex
# osmiumcoin
# dpay
# socialcoin
# chncoin
# dollar-online
# ego
# revenu
# destiny
# bnrtxcoin
# high-voltage
# biobar
# speedcash
# antilitecoin
# sydpak
# vaperscoin
# argus
# tradecoin
# bitvolt
# concoin
# px
# p7coin
# save-and-gain
# xonecoin
# nodecoin
# rawcoin
# elysium
# walletbuilder...
# powercoin
# pizzacoin
# swaptoken
# digital-credits
# sojourn
# abncoin
# ebittree-coin
# future-digita...
# caliphcoin
# environ
# fargocoin
# techshares
# firstcoin
# bt2-[cst]
# segwit2x-[fut...
# infinity-econ...
# aidos-kuneen
# swisscoin
# tezos-(pre-la...
# interstellar-...
# bt1-[cst]
# akuya-coin
# golos-gold
# msd
# alpacoin
# bitsoar
# sigmacoin
# deuscoin
# t-coin
# high-gain
# atmcoin
# russian-minin...
# pabyosi-coin-...
# blazercoin
# international...
# bitcoin-unlim...
# zilbercoin
# bastonet
# cheapcoin
# eggcoin
# gay-money
# bubble
# granite
# wa-space
# 9coin
# universalroya...
# ecc
# happy-creator...
# betacoin
# rcoin
# halloween-coin
# antimatter
# regacoin
# dutch-coin
# primulon
# irishcoin
# huncoin
# peacecoin
# dashs
# bitcoincashsc...
# india-coin
# fazzcoin
# netbit
# rabbitcoin
# coupecoin
# voyacoin
# landcoin
# skeincoin
# lazaruscoin
# xtd-coin
# sharkcoin
# batcoin
# futcoin
# bestchain
# aces
# zsecoin
# ganjacoin
# fireflycoin
# deltacredits
# moneycoin
# marxcoin
# wink
# yescoin
# xde-ii
# peepcoin
# first-bitcoin
# rublebit
# motocoin
# darklisk
# karmacoin
# flappycoin
# rupaya-[old]
# operand
# safecoin
# elacoin
# topaz-coin
# todaycoin
# axiom
# royalcoin
# ur
# turbocoin
# aseancoin
# wearesatoshi
# x2
# pinkdog
# golfcoin
# avatarcoin
# bitok
# shellcoin
# wowcoin
# safe-trade-coin
# mmxvi
# animecoin
# cycling-coin
# shacoin
# cubits
# bongger
# quotient
# uncoin
# ocow
# donationcoin
# the-vegan-ini...
# pokecoin
# invisiblecoin
# birds
# tellurion
# pirate-blocks
# advanced-inte...
# xaucoin
# gameleaguecoin
# mavro
# wowecoin
# tattoocoin-(l...
# mobilecash
# sportscoin
# topcoin
# fonziecoin
# asiccoin
# bitcentavo
# quebecoin
# vegascoin
# trickycoin
# cybercoin
# dubstep
# cashme
# opescoin
# bitalphacoin
# psilocybin
# paypeer
# thecreed
# clinton
# soulcoin
# richcoin
# prismchain
# digital-bulli...
# linkedcoin
# frankywillcoin
# ugain
# omicron
# lathaan
# teamup
# cbd-crystals
# global-busine...
# axfunds
# teracoin
# rhfcoin
# bixc
# picoin
# excelcoin
# microcoin
# mergecoin
# aureus

# %% [markdown]
# By inspection of the crypt-currencies that are do not have a github repository it can be seen that these crypt-currencies are those with the lower market caps.<br>
# For example in the top 50 crypto-currencies by marketcap only 3 do not have an active git repository.
# <br><br>
#
# *These are:*
# * Stellar-Lumens (no. 17 by market cap)
# * Byteball-btyes (no. 31 by market cap)
# * Metaverse-etp (no. 38by market cap)
# * Vechain (no. 47 by market cap)
#
# <br>
# **Note that over 95% of  the marketcap  of crypto-currencies is in the top 10 crypto currencies**

# %%
# We only want the crypto-currencies that have a Github repository.
# Hence we remove the crypto-currencies without a Github repo from the dictionary.
cryptoName_gitUrl_dict = {k:v for k,v in cryptoName_gitUrl_dict.items() if v is not None}

# %%
print('Number of crypto-currencies WITH a Github repo: ' + str(len(cryptoName_gitUrl_dict)))
print('')
print('')
print('Example entry:')
print(list(cryptoName_gitUrl_dict.items())[-0])
# Out:
# Number of crypto-currencies WITH a Github repo: 423
#
#
# Example entry:
# ('bitcoin', 'https://github.com/bitcoin/bitcoin')

# %%
# Re-pickle dict to current directory without "None" values() {'bitcoin: https://github.com/bitcoin/bitcoin}
with open('./cryptoName_gitUrl_dict.pickle', 'wb') as handle:
    pickle.dump(cryptoName_gitUrl_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# We are now  ready to carry out our inital analysis

# %%
print(cryptoName_gitUrl_dict)
# Out:
# {'bitcoin': 'https://github.com/bitcoin/bitcoin', 'ethereum': 'https://github.com/ethereum/go-ethereum', 'bitcoin-cash': 'https://github.com/Bitcoin-ABC/bitcoin-abc', 'ripple': 'https://github.com/ripple/rippled', 'litecoin': 'https://github.com/litecoin-project/litecoin', 'dash': 'https://github.com/dashpay/dash', 'neo': 'https://github.com/neo-project/neo', 'monero': 'https://github.com/monero-project/bitmonero', 'iota': 'https://github.com/iotaledger/wallet', 'nem': 'https://github.com/NewEconomyMovement/NemCommunityClient', 'ethereum-classic': 'https://github.com/ethereumproject/go-ethereum', 'lisk': 'https://github.com/LiskHQ/lisk', 'qtum': 'https://github.com/qtumproject/qtum', 'zcash': 'https://github.com/zcash/zcash', 'hshare': 'https://github.com/HcashOrg/Hshare', 'cardano': 'https://github.com/input-output-hk/cardano-sl', 'bitconnect': 'https://github.com/bitconnectcoin/bitconnectcoin', 'waves': 'https://github.com/wavesplatform/Waves', 'stratis': 'https://github.com/stratisproject/Breeze', 'ark': 'https://github.com/ArkEcosystem/ark-node', 'steem': 'https://github.com/steemit/steem', 'bitshares': 'https://github.com/BitShares/bitshares-2', 'komodo': 'https://github.com/jl777/komodo', 'bytecoin': 'https://github.com/amjuarez/bytecoin', 'decred': 'https://github.com/decred/dcrd', 'vertcoin': 'https://github.com/vertcoin/vertcoin', 'pivx': 'https://github.com/PIVX-Project/PIVX', 'monacoin': 'https://github.com/monacoinproject/monacoin', 'factom': 'https://github.com/FactomProject/factomd', 'dogecoin': 'https://github.com/dogecoin/dogecoin', 'bitcoindark': 'https://github.com/laowais/bitcoindark', 'siacoin': 'https://github.com/NebulousLabs/Sia', 'syscoin': 'https://github.com/syscoin/syscoin2', 'gamecredits': 'https://github.com/gamers-coin/GameCredits', 'blocknet': 'https://github.com/atcsecure/blocknet', 'lykke': 'https://github.com/LykkeCity/LykkeX', 'verge': 'https://github.com/vergecurrency/verge', 'gxshares': 'https://github.com/gxchain/gxb-core', 'digibyte': 'https://github.com/digibyte/digibyte', 'pura': 'https://github.com/PURAcore/PURA', 'zcoin': 'https://github.com/zcoinofficial/zcoin', 'nxt': 'https://bitbucket.com/JeanLucPicard/nxt', 'particl': 'https://github.com/particl/particl-core', 'zencash': 'https://github.com/ZencashOfficial/zen', 'nexus': 'https://github.com/Nexusoft/Nexus', 'faircoin': 'https://github.com/FairCoinTeam/fair-coin', 'nav-coin': 'https://github.com/NAVCoin/navcoin-core', 'bitdeal': '/bitdeal/', 'ubiq': 'https://github.com/ubiq/go-ubiq', 'neblio': 'https://github.com/NeblioTeam/-', 'counterparty': 'https://github.com/CounterpartyXCP/counterparty-lib', 'nolimitcoin': 'https://github.com/NoLimitCoin/NoLimitCoin', 'peercoin': 'https://github.com/peercoin/peercoin', 'bitbay': 'https://github.com/dzimbeck/BitBay', 'okcash': 'https://github.com/okcashpro/okcash', 'groestlcoin': 'https://github.com/GroestlCoin/GroestlCoin', 'viacoin': 'https://github.com/viacoin/viacoin', 'gulden': 'https://github.com/Gulden/gulden-official', 'reddcoin': 'https://github.com/reddcoin-project/reddcoin', 'achain': 'https://github.com/Achain-Dev/Achain', 'cloakcoin': 'https://github.com/CloakCoin/CloakCoinRelaunch', 'rise': 'https://github.com/RiseVision/rise-core', 'bitcore': 'https://github.com/LIMXTEC/BitCore', 'emercoin': 'https://github.com/EvgenijM86/emercoin', 'leocoin': 'https://github.com/Leocoin-project/LEOcoin', 'potcoin': 'https://github.com/potcoin/potcoin', 'elastic': 'https://github.com/elastic-coin/Elastic-Wallet', 'skycoin': 'https://github.com/skycoin/skycoin', 'aeon': 'https://github.com/aeonix/aeon', 'lbry-credits': 'https://github.com/lbryio/lbry', 'einsteinium': 'https://github.com/emc2foundation/qt-wallet-emc2', 'diamond': 'https://github.com/DMDcoin/Diamond', 'namecoin': 'https://github.com/Namecoin/namecoin-core', 'sibcoin': 'https://github.com/ivansib/sibcoin', 'feathercoin': 'https://github.com/FeatherCoin/Feathercoin', 'minexcoin': 'https://github.com/minexcoin/minexcoin', 'ion': 'htt ...

# %%
# Re-pickle dict to current directory without "None" values() {'bitcoin: https://github.com/bitcoin/bitcoin}
with open('./cryptoName_gitUrl_dict.pickle', 'rb') as handle:
    d = pickle.load(handle)

# %%
d['bitdeal']
# Out:
# '/bitdeal/'
